# %%
# %run train.py \
  --data_path data/ptbxl/100hz \
  --model resnet1d
# Out:
# ...
# ECG K-FOLD TRAINING
# ...
# Device        : cpu
# Dataset       : ptbxl
# Sampling rate : 100 Hz
# Model         : resnet1d
# ...
#
# === Fold 1/5 ===
# Train       : total=1916 | Normal=958 (50.00%) | AFIB=958 (50.00%)
# Validation  : total=476 | Normal=238 (50.00%) | AFIB=238 (50.00%)
#
# Epoch 01/30 | TrainLoss 0.3043 | ValLoss 0.2112 | ACC 92.23% | F1 0.9234 | Time 4.85s
# Epoch 02/30 | TrainLoss 0.1539 | ValLoss 0.1259 | ACC 95.80% | F1 0.9592 | Time 4.76s
# Epoch 03/30 | TrainLoss 0.1044 | ValLoss 0.1935 | ACC 91.18% | F1 0.9186 | Time 4.71s
# Epoch 04/30 | TrainLoss 0.0664 | ValLoss 0.0546 | ACC 98.74% | F1 0.9873 | Time 4.14s
# Epoch 05/30 | TrainLoss 0.0634 | ValLoss 0.0683 | ACC 97.90% | F1 0.9793 | Time 4.04s
# Epoch 06/30 | TrainLoss 0.0707 | ValLoss 0.0559 | ACC 97.90% | F1 0.9787 | Time 4.45s
# Epoch 07/30 | TrainLoss 0.0670 | ValLoss 0.0619 | ACC 97.69% | F1 0.9765 | Time 4.66s
# Epoch 08/30 | TrainLoss 0.0437 | ValLoss 0.0569 | ACC 98.32% | F1 0.9830 | Time 4.57s
# ...

# %% [markdown]
# ./run_all.sh > run_all.log 2>&1

# %%
# Out:
# Saved:
#  - all_results.csv
#  - all_results.xlsx
# Professional table generated successfully.
